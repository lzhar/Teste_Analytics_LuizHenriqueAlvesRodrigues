# %%
import limpeza_dados as lpd

# %% [markdown]
# ## 📊 Célula de Recuperação de Dados
#
# Essa é a **célula responsável** por recuperar meus dados do **script principal** 📝.
# Ela funciona como um ponto de integração entre o código central e este notebook, garantindo que os dados estejam disponíveis para análise e manipulação.

# %%
class Produto:

    def __init__(self, id, nome, categoria, preco):
        self.id = id
        self.nome = nome
        self.categoria = categoria
        self.preco = preco
class Dados:

    def __init__(self, id=None, data=None, produto=None, quantidade=None):
        self.id = id
        self.data = data
        self.produto = produto
        self.quantidade = quantidade

    def montar_data_set(self):    
        dados = lpd.Dados()
        daata_set = dados.montar_data_set()
        data_set_final = daata_set
        return data_set_final

    def retornar_produtos_sem_duplicata(self):
        data_set_vendas = self.montar_data_set()

        lista_de_produtos_vendidos_em_jan = []
        lista_de_produtos_vendidos_em_fev = []
        lista_de_produtos_vendidos_em_marc = []
        lista_de_produtos_vendidos_em_abril = []
        lista_de_produtos_vendidos_em_maio = []
        lista_de_produtos_vendidos_em_junho = []
        lista_de_produtos_vendidos_em_julho = []
        lista_de_produtos_vendidos_em_agosto = []
        lista_de_produtos_vendidos_em_set = []
        lista_de_produtos_vendidos_em_out = []
        lista_de_produtos_vendidos_em_nov = []
        lista_de_produtos_vendidos_em_dezemb = []

        
        modelo_dict_de_produtos_vendidos_em_jan = {}
        modelo_dict_de_produtos_vendidos_em_fev = {}
        modelo_dict_de_produtos_vendidos_em_marc = {}
        modelo_dict_de_produtos_vendidos_em_abril = {}
        modelo_dict_de_produtos_vendidos_em_maio = {}
        modelo_dict_de_produtos_vendidos_em_junho = {}
        modelo_dict_de_produtos_vendidos_em_julho = {}
        modelo_dict_de_produtos_vendidos_em_agosto = {}
        modelo_dict_de_produtos_vendidos_em_set = {}
        modelo_dict_de_produtos_vendidos_em_out = {}
        modelo_dict_de_produtos_vendidos_em_nov = {}
        modelo_dict_de_produtos_vendidos_em_dezemb = {}



        for mes, dados in data_set_vendas.items():

            match mes:
                case "janeiro":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_jan:
                            modelo_dict_de_produtos_vendidos_em_jan[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_jan[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_jan[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_jan[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_jan[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_jan.append(modelo_dict_de_produtos_vendidos_em_jan[produto_id])
                        contador+=1
                case "fevereiro":
                    contador = 0
                    
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_fev:
                            modelo_dict_de_produtos_vendidos_em_fev[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_fev[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_fev[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_fev[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_fev[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_fev.append(modelo_dict_de_produtos_vendidos_em_fev[produto_id])
                        contador+=1
                case "marco":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_marc:
                            modelo_dict_de_produtos_vendidos_em_marc[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_marc[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_marc[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_marc[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_marc[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_marc.append(modelo_dict_de_produtos_vendidos_em_marc[produto_id])
                        contador+=1
                case "abril":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_abril:
                            modelo_dict_de_produtos_vendidos_em_abril[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_abril[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_abril[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_abril[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_abril[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_abril.append(modelo_dict_de_produtos_vendidos_em_abril[produto_id])
                        contador+=1
                case "maio":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_maio:
                            modelo_dict_de_produtos_vendidos_em_maio[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_maio[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_maio[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_maio[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_maio[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_maio.append(modelo_dict_de_produtos_vendidos_em_maio[produto_id])
                        contador+=1
                case "junho":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_junho:
                            modelo_dict_de_produtos_vendidos_em_junho[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_junho[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_junho[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_junho[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_junho[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_junho.append(modelo_dict_de_produtos_vendidos_em_junho[produto_id])
                        contador+=1
                case "julho":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_julho:
                            modelo_dict_de_produtos_vendidos_em_julho[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_julho[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_julho[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_julho[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_julho[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_julho.append(modelo_dict_de_produtos_vendidos_em_julho[produto_id])
                        contador+=1
                case "agosto":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_agosto:
                            modelo_dict_de_produtos_vendidos_em_agosto[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_agosto[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_agosto[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_agosto[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_agosto[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_agosto.append(modelo_dict_de_produtos_vendidos_em_agosto[produto_id])
                        contador+=1
                case "setembro":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_set:
                            modelo_dict_de_produtos_vendidos_em_set[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_set[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_set[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_set[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_set[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_set.append(modelo_dict_de_produtos_vendidos_em_set[produto_id])
                        contador+=1
                case "outubro":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_out:
                            modelo_dict_de_produtos_vendidos_em_out[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_out[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_out[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_out[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_out[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_out.append(modelo_dict_de_produtos_vendidos_em_out[produto_id])
                        contador+=1
                case "novembro":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_nov:
                            modelo_dict_de_produtos_vendidos_em_nov[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_nov[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_nov[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_nov[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_nov[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_nov.append(modelo_dict_de_produtos_vendidos_em_nov[produto_id])
                        contador+=1
                case "dezembro":
                    contador = 0
                    while (contador < len(dados)):

                        produto_id = dados[contador].produto.id
                        produto_qtd = dados[contador].quantidade
                        produto_preco = dados[contador].produto.preco
                        produto_nome = dados[contador].produto.nome
                        produto_categoria = dados[contador].produto.categoria

                        if produto_id in modelo_dict_de_produtos_vendidos_em_dezemb:
                            modelo_dict_de_produtos_vendidos_em_dezemb[produto_id]["qtd"] += produto_qtd
                            modelo_dict_de_produtos_vendidos_em_dezemb[produto_id]["preco_total_de_vendas"] = round(\
                            modelo_dict_de_produtos_vendidos_em_dezemb[produto_id]["qtd"] * modelo_dict_de_produtos_vendidos_em_dezemb[produto_id]["preco"], 2)
                        else:
                            modelo_dict_de_produtos_vendidos_em_dezemb[produto_id] = {
                                "id": produto_id,
                                "nome_produto" : produto_nome,
                                "produto_categoria" : produto_categoria,
                                "qtd": produto_qtd,
                                "preco" : produto_preco,
                                "mes" : mes
                            }
                            lista_de_produtos_vendidos_em_dezemb.append(modelo_dict_de_produtos_vendidos_em_dezemb[produto_id])
        
                        contador+=1
        
        lista_de_todos_meses = [lista_de_produtos_vendidos_em_jan, lista_de_produtos_vendidos_em_fev, lista_de_produtos_vendidos_em_marc,
                                lista_de_produtos_vendidos_em_abril, lista_de_produtos_vendidos_em_maio, lista_de_produtos_vendidos_em_junho,  
                                lista_de_produtos_vendidos_em_julho,  lista_de_produtos_vendidos_em_agosto,  lista_de_produtos_vendidos_em_set,
                                 lista_de_produtos_vendidos_em_out,  lista_de_produtos_vendidos_em_nov,  lista_de_produtos_vendidos_em_dezemb]


        return lista_de_todos_meses


dados = Dados()
dados.retornar_produtos_sem_duplicata()
# Out:
# [[{'id': 10,
#    'nome_produto': 'Multivitamínico Centrum',
#    'produto_categoria': 'Produtos de bem-estar',
#    'qtd': 64,
#    'preco': 29.9,
#    'mes': 'janeiro',
#    'preco_total_de_vendas': 1913.6},
#   {'id': 3,
#    'nome_produto': 'Ibuprofeno 400mg',
#    'produto_categoria': 'Medicamentos',
#    'qtd': 58,
#    'preco': 8.9,
#    'mes': 'janeiro',
#    'preco_total_de_vendas': 516.2},
#   {'id': 17,
#    'nome_produto': 'Álcool 70%',
#    'produto_categoria': 'Produtos hospitalares e de primeiros socorros',
#    'qtd': 26,
#    'preco': 3.9,
#    'mes': 'janeiro',
#    'preco_total_de_vendas': 101.4},
#   {'id': 5,
#    'nome_produto': 'Shampoo Seda',
#    'produto_categoria': 'Produtos de higiene pessoal',
#    'qtd': 71,
#    'preco': 9.95,
#    'mes': 'janeiro',
#    'preco_total_de_vendas': 706.45},
#   {'id': 21,
#    'nome_produto': 'Suco de Laranja Del Valle',
#    'produto_categoria': 'Produtos de conveniência',
#    'qtd': 51,
#    'preco': 4.9,
# ...

# %% [markdown]
# ### 🧮 Cálculo de Produto Mais Vendido por Mês
#
# Essa é a célula responsável por calcular **qual produto foi mais vendido em cada mês** 📊.
#
# Ela retorna **uma lista**, que é composta de outras listas 🗂️, e cada uma guarda um **dicionário (`dict`)** com os seguintes valores:
#
# - 🆔 **id**
# - 🏷️ **nome_produto**
# - 🗂️ **produto_categoria**
# - 📦 **qtd**
# - 💰 **preco**
# - 📅 **mes**
# - 💵 **preco_total_de_vendas**

# %%
class Calculos:

    def __init__(self, classe_base):
        self.classe_base = classe_base

    def calcular_total_produtos(self):
        produtos = []
        lista_de_dados = self.classe_base.retornar_produtos_sem_duplicata()

        for mes in lista_de_dados:
            for registro in mes:
                if registro["id"] in produtos:
                    continue
                else:
                    produtos.append(registro["id"])


        return produtos


    def calcular_produto_mais_vendido_de_cada_mes(self):
        produtos = sorted(self.calcular_total_produtos())

        produto_mais_ven_jan = []
        produto_mais_ven_fev = []
        produto_mais_ven_marco = []
        produto_mais_ven_abril = []
        produto_mais_ven_maio = []
        produto_mais_ven_junho = []
        produto_mais_ven_julho = []
        produto_mais_ven_agosto = []
        produto_mais_ven_setembro = []
        produto_mais_ven_out = []
        produto_mais_ven_nov = []
        produto_mais_ven_dezem = []



        produtos_sem_duplicata = self.classe_base.retornar_produtos_sem_duplicata()

        for item in produtos_sem_duplicata:
            for registro in item:
                mes = registro["mes"]
                
                for produto in item:
                    if mes == "janeiro":
                        if len(produto_mais_ven_jan) == 0: 
                            produto_mais_ven_jan.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_jan[0]["qtd"]:
                            del(produto_mais_ven_jan[0])
                            produto_mais_ven_jan.append(produto)
                    
                    if mes == "fevereiro":
                        if len(produto_mais_ven_fev) == 0: 
                            produto_mais_ven_fev.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_fev[0]["qtd"]:
                            del(produto_mais_ven_fev[0])
                            produto_mais_ven_fev.append(produto)
                    
                    if mes == "marco":
                        if len(produto_mais_ven_marco) == 0: 
                            produto_mais_ven_marco.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_marco[0]["qtd"]:
                            del(produto_mais_ven_marco[0])
                            produto_mais_ven_marco.append(produto)
                    
                    if mes == "abril":
                        if len(produto_mais_ven_abril) == 0: 
                            produto_mais_ven_abril.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_abril[0]["qtd"]:
                            del(produto_mais_ven_abril[0])
                            produto_mais_ven_abril.append(produto)
                    
                    if mes == "maio":
                        if len(produto_mais_ven_maio) == 0: 
                            produto_mais_ven_maio.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_maio[0]["qtd"]:
                            del(produto_mais_ven_maio[0])
                            produto_mais_ven_maio.append(produto)

                    if mes == "junho":
                        if len(produto_mais_ven_junho) == 0: 
                            produto_mais_ven_junho.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_junho[0]["qtd"]:
                            del(produto_mais_ven_junho[0])
                            produto_mais_ven_junho.append(produto)

                    if mes == "julho":
                        if len(produto_mais_ven_julho) == 0: 
                            produto_mais_ven_julho.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_julho[0]["qtd"]:
                            del(produto_mais_ven_julho[0])
                            produto_mais_ven_julho.append(produto)
                    
                    if mes == "agosto":
                        if len(produto_mais_ven_agosto) == 0: 
                            produto_mais_ven_agosto.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_agosto[0]["qtd"]:
                            del(produto_mais_ven_agosto[0])
                            produto_mais_ven_agosto.append(produto)

                    if mes == "setembro":
                        if len(produto_mais_ven_setembro) == 0: 
                            produto_mais_ven_setembro.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_setembro[0]["qtd"]:
                            del(produto_mais_ven_setembro[0])
                            produto_mais_ven_setembro.append(produto)

                    if mes == "outubro":
                        if len(produto_mais_ven_out) == 0: 
                            produto_mais_ven_out.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_out[0]["qtd"]:
                            del(produto_mais_ven_out[0])
                            produto_mais_ven_out.append(produto)

                    if mes == "novembro":
                        if len(produto_mais_ven_nov) == 0: 
                            produto_mais_ven_nov.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_nov[0]["qtd"]:
                            del(produto_mais_ven_nov[0])
                            produto_mais_ven_nov.append(produto)

                    if mes == "dezembro":
                        if len(produto_mais_ven_dezem) == 0: 
                            produto_mais_ven_dezem.append(produto)
                            break
                        if produto["qtd"] > produto_mais_ven_dezem[0]["qtd"]:
                            del(produto_mais_ven_dezem[0])
                            produto_mais_ven_dezem.append(produto)

        lista_de_todos_mais_vendidos = [produto_mais_ven_jan, produto_mais_ven_fev, 
                                        produto_mais_ven_marco, produto_mais_ven_abril, produto_mais_ven_maio, produto_mais_ven_junho, 
                                        produto_mais_ven_julho, produto_mais_ven_agosto, produto_mais_ven_setembro, 
                                        produto_mais_ven_out, produto_mais_ven_nov, produto_mais_ven_dezem]
        
        print("O produto mais vendido no mês de",lista_de_todos_mais_vendidos[0][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[0][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[0][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[0][0]["preco_total_de_vendas"], "R$", 
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[1][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[1][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[1][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[1][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[2][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[2][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[2][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[2][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[3][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[3][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[3][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[3][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[4][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[4][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[4][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[4][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[5][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[5][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[5][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[5][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[6][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[6][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[6][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[6][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[7][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[7][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[7][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[7][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[8][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[8][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[8][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[8][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[8][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[8][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[8][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[8][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[9][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[9][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[9][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[9][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[10][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[10][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[10][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[10][0]["preco_total_de_vendas"], "R$",
              "--------------------------------------------------------------",
              "O produto mais vendido no mês de",lista_de_todos_mais_vendidos[11][0]["mes"], "foi o -> ", lista_de_todos_mais_vendidos[11][0]["nome_produto"],
              "com ", lista_de_todos_mais_vendidos[11][0]["qtd"], "vendidos, gerando um total de ", lista_de_todos_mais_vendidos[11][0]["preco_total_de_vendas"], "R$")
        return lista_de_todos_mais_vendidos

# %% [markdown]
# ## 📊 Célula de Geração de Gráficos
#
# Esta célula é responsável por **montar os gráficos** utilizando a biblioteca `matplotlib`.
# ➡️ É dado um **ponto de entrada** para o usuário informar o **código do produto** que deseja verificar.
#
# Assim, o gráfico exibirá o **desempenho de vendas** desse produto ao longo dos meses. 🚀

# %%
import matplotlib.pyplot as plt


class Graficos:

    def __init__(self, mes=None):
        self.mes = mes

    def montar_dados_de_cada_prod(self):
        dados = Dados()
        dados_das_vendas = dados.retornar_produtos_sem_duplicata()
        print(dados_das_vendas)


        vendas_do_produto_1 = []
        vendas_do_produto_2 = []
        vendas_do_produto_3 = []
        vendas_do_produto_4 = []
        vendas_do_produto_5 = []
        vendas_do_produto_6 = []
        vendas_do_produto_7 = []
        vendas_do_produto_8 = []
        vendas_do_produto_9 = []
        vendas_do_produto_10 = []
        vendas_do_produto_11 = []
        vendas_do_produto_12 = []
        vendas_do_produto_13 = []
        vendas_do_produto_14 = []
        vendas_do_produto_15 = []
        vendas_do_produto_16 = []
        vendas_do_produto_17 = []
        vendas_do_produto_18 = []
        vendas_do_produto_19 = []
        vendas_do_produto_20 = []
        vendas_do_produto_21 = []


        for registro in dados_das_vendas:
            for dado in registro:
                if dado["id"] == 1:
                    vendas_do_produto_1.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 2:
                    vendas_do_produto_2.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 3:
                    vendas_do_produto_3.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 4:
                    vendas_do_produto_4.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 5:
                    vendas_do_produto_5.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 6:
                    vendas_do_produto_6.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 7:
                    vendas_do_produto_7.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 8:
                    vendas_do_produto_8.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })

                if dado["id"] == 9:
                    vendas_do_produto_9.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 10:
                    vendas_do_produto_10.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 11:
                    vendas_do_produto_11.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 12:
                    vendas_do_produto_12.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 13:
                    vendas_do_produto_13.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 14:
                    vendas_do_produto_14.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 15:
                    vendas_do_produto_15.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 16:
                    vendas_do_produto_16.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 17:
                    vendas_do_produto_17.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 18:
                    vendas_do_produto_18.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 19:
                    vendas_do_produto_19.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 20:
                    vendas_do_produto_20.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                if dado["id"] == 21:
                    vendas_do_produto_21.append({
                        "qtd" : dado["qtd"], 
                        "mes" : dado["mes"],
                        "nome_prod" : dado["nome_produto"]
                    })
                
        lista = [vendas_do_produto_1, vendas_do_produto_2, vendas_do_produto_3, 
                    vendas_do_produto_4, vendas_do_produto_5, vendas_do_produto_6, 
                    vendas_do_produto_7,vendas_do_produto_8, vendas_do_produto_9, 
                    vendas_do_produto_10, vendas_do_produto_11, vendas_do_produto_12,
                    vendas_do_produto_13, vendas_do_produto_14, vendas_do_produto_15,
                    vendas_do_produto_16, vendas_do_produto_17, vendas_do_produto_18,
                    vendas_do_produto_19, vendas_do_produto_20, vendas_do_produto_21,]
        return lista
    

    def criar_grafico_determindado_prod(self, prod_cod):
        
        dados_vendas = self.montar_dados_de_cada_prod()
        print(dados_vendas)


        meses = [
        "Janeiro", "Fevereiro", "Março", "Abril", "Maio", "Junho",
        "Julho", "Agosto", "Setembro", "Outubro", "Novembro", "Dezembro"
    ]

        dado = dados_vendas[prod_cod][0]["qtd"]
        print(dado)

        vendas = [dados_vendas[prod_cod][0]["qtd"], dados_vendas[prod_cod][1]["qtd"], dados_vendas[prod_cod][2]["qtd"], dados_vendas[prod_cod][3]["qtd"],
                  dados_vendas[prod_cod][4]["qtd"], dados_vendas[prod_cod][5]["qtd"], dados_vendas[prod_cod][6]["qtd"], dados_vendas[prod_cod][7]["qtd"],
                  dados_vendas[prod_cod][8]["qtd"], dados_vendas[prod_cod][9]["qtd"], dados_vendas[prod_cod][10]["qtd"], dados_vendas[prod_cod][11]["qtd"] ]   

        plt.figure(figsize=(12,9))

        # Agora o eixo X é "meses" e o Y são as "vendas"
        plt.plot(meses, vendas, marker="o", linestyle="-", color="b", label="Vendas")

        # Títulos e legendas
        nome_do_produto = dados_vendas[prod_cod][0]["nome_prod"]
        
        plt.title(f"📊 Desempenho de vendas de {nome_do_produto}", fontsize=14)
        plt.xlabel("Meses")
        plt.ylabel("Total de Vendas (Qtd)")
        plt.legend()
        plt.grid(True, linestyle="--", alpha=0.6)

        # Mostrar gráfico
        plt.show()



codigo_prod = input("Digite aqui um código do produto, de 0 a 20 para ver o desempenho dele no ano: ")
graficos = Graficos()
graficos.criar_grafico_determindado_prod(int(codigo_prod))
# Out:
# [[{'id': 10, 'nome_produto': 'Multivitamínico Centrum', 'produto_categoria': 'Produtos de bem-estar', 'qtd': 64, 'preco': 29.9, 'mes': 'janeiro', 'preco_total_de_vendas': 1913.6}, {'id': 3, 'nome_produto': 'Ibuprofeno 400mg', 'produto_categoria': 'Medicamentos', 'qtd': 58, 'preco': 8.9, 'mes': 'janeiro', 'preco_total_de_vendas': 516.2}, {'id': 17, 'nome_produto': 'Álcool 70%', 'produto_categoria': 'Produtos hospitalares e de primeiros socorros', 'qtd': 26, 'preco': 3.9, 'mes': 'janeiro', 'preco_total_de_vendas': 101.4}, {'id': 5, 'nome_produto': 'Shampoo Seda', 'produto_categoria': 'Produtos de higiene pessoal', 'qtd': 71, 'preco': 9.95, 'mes': 'janeiro', 'preco_total_de_vendas': 706.45}, {'id': 21, 'nome_produto': 'Suco de Laranja Del Valle', 'produto_categoria': 'Produtos de conveniência', 'qtd': 51, 'preco': 4.9, 'mes': 'janeiro', 'preco_total_de_vendas': 249.9}, {'id': 8, 'nome_produto': 'Base Vult', 'produto_categoria': 'Produtos de beleza', 'qtd': 70, 'preco': 35.9, 'mes': 'jan
# ...

# %% [markdown]
# ### 🗄️ Célula de Banco de Dados
#
# Essa célula cria um banco SQLite3, abre a conexão, define a tabela, carrega os dados de um arquivo CSV, aplica as alterações e no final fecha a conexão.

# %%
import sqlite3
import csv

caminho_csv = "data_clean.csv"  # substitua pelo caminho real


conn = sqlite3.connect("dbvendas")
curs = conn.cursor()

curs.execute("""
    CREATE TABLE produtos (
        id INTEGER PRIMARY KEY,
        data TEXT,
        produto_nome TEXT,
        produto_categoria TEXT,
        produto_preco REAL,
        quantidade INTEGER,
        mes TEXT
    )
""")

with open(caminho_csv, newline='', encoding='utf-8') as csvfile:
    leitor = csv.DictReader(csvfile)
    for linha in leitor:
        curs.execute("""
            INSERT INTO produtos (id, data, produto_nome, produto_categoria, produto_preco, quantidade, mes)
            VALUES (?, ?, ?, ?, ?, ?, ?)
        """, (
            int(linha['id']),
            linha['data'],
            linha['produto_nome'],
            linha['produto_categoria'],
            float(linha['produto_preco']),
            int(linha['quantidade']),
            linha['mes']
        ))

conn.commit()


curs.execute("SELECT * FROM produtos")
rows = curs.fetchall()
for row in rows:
    print(row)


conn.close()
# Out:
# (1, '2023-01-01', 'Multivitamínico Centrum', 'Produtos de bem-estar', 29.9, 4, 'janeiro')
# (2, '2023-01-01', 'Ibuprofeno 400mg', 'Medicamentos', 8.9, 12, 'janeiro')
# (3, '2023-01-01', 'Álcool 70%', 'Produtos hospitalares e de primeiros socorros', 3.9, 7, 'janeiro')
# (4, '2023-01-02', 'Shampoo Seda', 'Produtos de higiene pessoal', 9.95, 19, 'janeiro')
# (5, '2023-01-02', 'Suco de Laranja Del Valle', 'Produtos de conveniência', 4.9, 25, 'janeiro')
# (6, '2023-01-03', 'Base Vult', 'Produtos de beleza', 35.9, 3, 'janeiro')
# (7, '2023-01-03', 'Lenço Umedecido Huggies', 'Produtos para bebês', 9.9, 44, 'janeiro')
# (8, '2023-01-04', 'Paracetamol 500mg', 'Medicamentos', 7.5, 6, 'janeiro')
# (9, '2023-01-04', 'Chocolate Snickers', 'Produtos de conveniência', 5.49, 18, 'janeiro')
# (10, '2023-01-05', 'Batom Maybelline', 'Produtos de beleza', 29.9, 9, 'janeiro')
# (11, '2023-01-05', 'Chá de Camomila', 'Produtos de bem-estar', 4.9, 30, 'janeiro')
# ...
